// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
double S = 200;
int N = 5;
double J = 0.01;
double parcelaAtual = S;
        
for (int i = 1; i <= N; i++) {
    parcelaAtual = (parcelaAtual * (1 + J));
    System.out.printf("%dº parcela: %.2f\n",i,parcelaAtual);
}
// Out:
// 1º parcela: 202.00
// 2º parcela: 204.02
// 3º parcela: 206.06
// 4º parcela: 208.12
// 5º parcela: 210.20
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Emprestimo {
    static double calculaParcela(int parcelaX, double S, double J) {
        return S * (Math.pow(1 + J, parcelaX));
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9744d940.Emprestimo

// %%
double emprestimo = Emprestimo.calculaParcela(5, 200, 0.01);
System.out.printf("%.2f \n", emprestimo);
// Out:
// 210.20
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
import java.util.Random;

Random rand = new Random();
int upperbound = 10000;
int int_random = rand.nextInt(upperbound) + 1; 

System.out.printf("o número sorteado é: %d\n", int_random);



int resto;
int quocienteInteiro = int_random;
String binario = "";

while (quocienteInteiro != 0) {
    resto = quocienteInteiro % 2;
    quocienteInteiro = quocienteInteiro / 2;
    
    binario = resto + binario;
}

System.out.printf("%d convertido para binário é: %s", int_random, binario);
// Out:
// o número sorteado é: 4662
// 4662 convertido para binário é: 1001000110110
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class RNA {
    static String decodificarDna(String dna) {
        String rna = "";
        for (int i = 0; i < dna.length(); i++) {
            char base = dna.charAt(i);
            
            switch(base) {
                case 'A':
                    rna = rna + "U";
                    break;
                case 'T':
                    rna = rna + "A";
                    break;
                case 'C':
                    rna = rna + "G";
                    break;
                case 'G':
                    rna = rna + "C";
                    break;
                
            }
        }
        
        return rna;
    }
}
// Out:
// com.twosigma.beaker.javash.bkr9744d940.RNA

// %%
String DNA = "AATTCCGGA";
String rnaDecodificado = RNA.decodificarDna(DNA);
System.out.println(rnaDecodificado);
// Out:
// UUAAGGCCU
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

Random rand = new Random();

int[] salarios = new int[50];
int totalSalario = 0;
int upperbound = 15001 - 2500;
for (int i = 0; i < 50 ; i++) {
    int salario = rand.nextInt(upperbound) + 2500;
    salarios[i] = salario;
    System.out.printf("O %dº funcionario ganha: R$%d \n", i + 1, salario);
    
    totalSalario += salario;
}

double media = (double)totalSalario / 50;
System.out.printf("\nA média é R$%.2f", media);

int acimaDaMedia = 0;

for (int i = 0; i < 50; i++) {
    if (salarios[i] > media) acimaDaMedia++;
}

System.out.printf("\n\n%d funcionarios ganham acima da média\n", acimaDaMedia);
// Out:
// O 1º funcionario ganha: R$4258
// O 2º funcionario ganha: R$8478
// O 3º funcionario ganha: R$12961
// O 4º funcionario ganha: R$12971
// O 5º funcionario ganha: R$9232
// O 6º funcionario ganha: R$10291
// O 7º funcionario ganha: R$8911
// O 8º funcionario ganha: R$8505
// O 9º funcionario ganha: R$14953
// O 10º funcionario ganha: R$5947
// O 11º funcionario ganha: R$8836
// O 12º funcionario ganha: R$4312
// O 13º funcionario ganha: R$13104
// O 14º funcionario ganha: R$2539
// O 15º funcionario ganha: R$8363
// O 16º funcionario ganha: R$6575
// O 17º funcionario ganha: R$6636
// O 18º funcionario ganha: R$5316
// O 19º funcionario ganha: R$8666
// O 20º funcionario ganha: R$2907
// O 21º funcionario ganha: R$10920
// O 22º funcionario ganha: R$12707
// O 23º funcionario ganha: R$5901
// O 24º funcionario ganha: R$3323
// O 25º funcionario ganha: R$3003
// O 26º funcionario ganha: R$7245
// O 27º funcionario ganha: R$5201
// O 28º funcionario ganha: R$14744
// O 29º funcionario ganha: R$11746
// O 30º funcionario ganha: R$6031
// O 31º funcionario ganha: R$2613
// O 32º funcionario ganha: R$10834
// O 33º funcionario ganha: R$14935
// O 34º funcionario ganha: R$13442
// O 35º funcionario ganha: R$7521
// O 36º funcionario ganha: R$2867
// O 37º funcionario ganha: R$12007
// O 38º funcionario ganha: R$10412
// O 39º funcionario ganha: R$12563
// O 40º funcionario ganha: R$5160
// O 41º funcionario ganha: R$12470
// O 42º funcionario ganha: R$13109
// O 43º funcionario ganha: R$7675
// O 44º funcionario ganha: R$4789
// O 45º funcionario ganha: R$13598
// O 46º funcionario ganha: R$7205
// O 47º funcionario ganha: R$12869
// O 48º funcionario ganha: R$4837
// O 49º funcionario ganha: R$2888
// O 50º funcionario ganha: R$13618
//
// A média é R$8599.88
//
// 24 funcionarios ganham acima da média
// null
